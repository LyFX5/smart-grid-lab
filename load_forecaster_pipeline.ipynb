# %%
import pandas as pd
import stef (?)

# %% [markdown]
# # Load data

# %% [markdown]
# # Devide Train Test Validate

# %% [markdown]
# # Train the model

# %% [markdown]
# # Test

# %% [markdown]
# # Plot results

# %% [markdown]
# # Validate

# %% [markdown]
# # Plot result

# %% [markdown]
# # Finalize the Inference -> into infrastructure
